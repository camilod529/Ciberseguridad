# %% [markdown]
# # Camilo Alberto Duran Ferreira
# # Funciones

# %%
import random
from math import gcd

def isPrime(n):
    if n > 1:
        for i in range(2, n):
            if (n % i) == 0:
                return False
        else:
            return True
    else:
        return False

def modExp(base, exp, modulus):
    result = 1
    while exp > 0:
        if exp % 2 == 1:
            result = (result * base) % modulus
        base = (base * base) % modulus
        exp = exp // 2
    return result

def maxCommonDivisor(a, b):
    while b != 0:
        a, b = b, a % b
    return a

def inverseMultiplicative(a, b):
    for i in range(1, b):
        if (a * i) % b == 1:
            return i
        
    return -1

def descifrarMod27():
    alfabeto = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ abcdefghijklmnopqrstuvwxyz '
    mensajeCifrado = ''
    for letra in mensajeCifradoMod:
        if letra in alfabeto:
            indice = alfabeto.index(letra)
            indiceDes = (indice - desplazamiento_mod) % 27
            letraDes = alfabeto[indiceDes]
            mensajeCifrado += letraDes
        else:
            mensajeCifrado += letra
    print('Mensaje descifrado : ' , mensajeCifrado)  
    print("\nIngrese cualquier tecla para continuar...")
    input()

def descifrarCesar():
    alfabeto = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
    mensajeDescifrado = ''
    for letraCifrada in mensajeCifradoCesar:
        if letraCifrada in alfabeto:
            indiceCifrado = alfabeto.index(letraCifrada)
            indiceDescifrado = (indiceCifrado - desplazamiento_cesar) % 26
            letraDescifrada = alfabeto[indiceDescifrado]
            mensajeDescifrado += letraDescifrada
        else:
            mensajeDescifrado += letraCifrada
    print('Mensaje descifrado : ', mensajeDescifrado)
    print("\nIngrese cualquier tecla para continuar...")
    input()

def descifrarVernam():
    bitesEncriptado = bytes.fromhex(encrypted_vernam)
    bytesClave = bytes.fromhex(key_vernam)

    bytesDecryptados = bytes([bitesEncriptado[i] ^ bytesClave[i] for i in range(len(bitesEncriptado))])

    print("Mensaje descifrado : ", bytesDecryptados.decode())
    print("\nIngrese cualquier tecla para continuar...")
    input()

def p11():
    print("1.1 Calcular el módulo de dos números a mod n = b")

    a= int(input("Ingrese un numero "))
    n= int(input("Ingrese el modulo "))
    b = a % n
    print(f"\n El módulo de {a} mod {n} = {b}")

def p12():
    print("1.2 Calcular inverso aditivo")

    n= int(input("Ingrese un numero "))
    ia = -1 * n
    r = n + (ia)
    print(f"\n El inverso aditivo de {n} es {ia}")
    print(f" El resultado de la suma es {r}")

def p13():
    print("1.3 Calcular inverso de XOR")

    a= input("Ingrese el primer valor en binario ")
    b= input("Ingrese el segundo valor en binario ")

    a = int(a, 2)
    b = int(b, 2)

    
    x = a ^ b
    
    y = x ^ b

    print(f"\n El resultado de XOR es {bin(x)}")
    print(f" El resultado del inverso de XOR es {bin(y)}")

def p14():
    print("1.4 Calcular máximo común divisor (MCD) e indicar si existe el inverso multiplicativo")
    a=int(input("Ingrese el primer número "))
    b=int(input("Ingrese el segundo número "))
    while b != 0:
        a, b = b, a % b
    print("MCD: " + str(a))
    if(a>1):
      print("No existe el inverso multiplicativo")
    else:
      print("Existe el inverso multiplicativo")
    input()

def p15():
    a = int(input("\nIngrese un valor de la base: "))
    b = int(input("Ingrese un valor del módulo: "))

    c = []

    print("\nTabla de multiplicaciones:")
    for i in range(1, b):
        d = a * i % b
        c.append(d)
        print(str(a) + " * " + str(i) + " % " + str(b) + " = " + str(d))

    if (1 in c):
        print("\nEl inverso multiplicativo de", a, "mod", b, "es", c.index(1) + 1)
    else:
        print("\nNo existe inverso multiplicativo")

    print("\nIngrese cualquier tecla para continuar...")
    input()

def p16():
    print("Calcular inverso multiplicativo aplicando el Algoritmo Extendido de Euclides")
    print("Ingrese el primer número")
    a = int(input())

    print("Ingrese el segundo número")
    b = int(input())

    count = 0
    i = []
    yi = []
    gi = []
    ui = []
    vi = []

    i.append(0)
    i.append(1)

    gi.append(b)
    gi.append(a)

    ui.append(1)
    ui.append(0)

    vi.append(0)
    vi.append(1)

    print("i     yi     gi     ui     vi")
    print(str(i[-2]) + "     -     " + str(gi[-2]) + "     " + str(ui[-2]) + "     " + str(vi[-2]))
    print(str(i[-1]) + "     -     " + str(gi[-1]) + "     " + str(ui[-1]) + "     " + str(vi[-1]))

    while(gi[-1] != 0):
        count = count + 1
        i.append(len(i))

        yi.append(gi[-2] // gi[-1])
        gi.append(gi[-2] % gi[-1])

        ui.append(ui[-2] - yi[-1] * ui[-1])
        vi.append(vi[-2] - yi[-1] * vi[-1])

        print(str(i[-1]) + "     " + str(yi[-1]) + "     " + str(gi[-1]) + "     " + str(ui[-1]) + "     " + str(vi[-1]))

    print("Cantidad de rondas: " + str(count))
    print("El inverso es " + str(vi[-2] + vi[-1]))

def p21():
    print("2.1 cifrado Módulo 27")
    global mensajeCifradoMod
    global desplazamiento_mod
    mensaje = input('Mensaje a Cifrar : ')
    desplazamiento_mod = int(input('Ingrese el desplazamiento'))
    alfabeto = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ abcdefghijklmnopqrstuvwxyz'
    mensajeCifradoMod = ''
    for letra in mensaje:
        
        if letra in alfabeto:
            indice = alfabeto.index(letra)
            indice_cifrado = (indice + desplazamiento_mod) % 27
            letra_cifrada = alfabeto[indice_cifrado]            
            mensajeCifradoMod += letra_cifrada
          
        else:
            mensajeCifradoMod += letra
             
    print('Mensaje cifrado : ', mensajeCifradoMod)
  
def p22():
  print("2.2 cifrado Cesar")
  global  desplazamiento_cesar
  global mensajeCifradoCesar  
  alfabeto = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
  mensaje = input('Ingrese el mensaje a cifrar: ')
  desplazamiento_cesar = int(input('Ingrese el desplazamiento para el cifrado: '))
  mensajeCifradoCesar = ''

  for letra in mensaje:
        if letra in alfabeto:
            indice = alfabeto.index(letra)
            indice_cifrado = (indice + desplazamiento_cesar) % 26
            letra_cifrada = alfabeto[indice_cifrado]
            mensajeCifradoCesar += letra_cifrada
        else:
            # Si la letra no es una letra del alfabeto, añadirla directamente al mensaje cifrado
            mensajeCifradoCesar += letra

  print(mensajeCifradoCesar)

def p23():
    print("2.3 cifrado vernam")
    message = input("Ingresa el mensaje a cifrar")
    message_bytes = message.encode()
    key_bytes = bytes([random.randint(0, 255) for _ in range(len(message_bytes))])
    encrypted_bytes = bytes([message_bytes[i] ^ key_bytes[i] for i in range(len(message_bytes))])
    global  encrypted_vernam
    global key_vernam
    encrypted_vernam = encrypted_bytes.hex()
    key_vernam = key_bytes.hex()
    print("Mensaje cifrado:",encrypted_vernam,"Clave para e crifrado : ", key_vernam)

def p24():
  message = input('Escriba un mensaje sin espacios: ') 
  def Catbash(message):     
      ABC = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ' 
      ZYX = 'ZYXWVUTSRQPONMLKJIHGFEDCBA' 
      cifrado = '' 

      for letter in message:
          cifrado += ZYX[ABC.index(letter)]
          
      return cifrado
  print(f'Resultado: { Catbash(message.upper()) }') 

def p25():
  import math


  def encrypt(msg, key):
    len_msg = len(msg)
    rows = math.ceil(len_msg / key)
    matrix = [[' ' for _ in range(key)] for _ in range(rows)]
    k = 0


    for i in range(rows):
        for j in range(key):
            if k < len_msg:
                matrix[i][j] = msg[k]
                k += 1


    cipher = ''
    for j in range(key):
        for i in range(rows):
            cipher += matrix[i][j]

    return cipher
    
  def decrypt(cipher, key):
    len_cipher = len(cipher)
    rows = math.ceil(len_cipher / key) 
    matrix = [[' ' for _ in range(key)] for _ in range(rows)] 
    k = 0 

    
    for j in range(key):
        for i in range(rows):
            if k < len_cipher:
                matrix[i][j] = cipher[k]
                k += 1

    
    msg = ''
    for i in range(rows):
        for j in range(key):
            msg += matrix[i][j]

    return msg.rstrip()
    
  msg = input("Ingrese el mensaje a cifrar: ")
  key = int(input("Ingrese la clave (un número entero mayor que 0): "))

  
  cipher = encrypt(msg, key)
  print("Mensaje cifrado:", cipher)

  msg_decrypted = decrypt(cipher, key)
  print("Mensaje descifrado:", msg_decrypted)

def p26():
    print("2.6 cifrado afin")
    
    def mcd(a, b):
      x,y, u,v = 0,1, 1,0
      while a != 0:
          q, r = b//a, b%a
          m, n = x-u*q, y-v*q
          b,a, x,y, u,v = a,r, u,v, m,n
      gcd = b
      return gcd, x, y
 
    def inv(a, m):
      gcd, x, y = mcd(a, m)
      if gcd != 1:
          return None # No existe el inverso multiplicativo
      else:
          return x % m
 
    def encrypt(mensaje, clave):
      #C = (a*P + b) % 26
      return ''.join([ chr((( clave[0]*(ord(t) - ord('A')) + clave[1] ) % 26) + ord('A')) for t in mensaje.upper().replace(' ', '') ])
 
 
    def decrypt(mensaje_encriptado, clave):
      #P = (a^-1 * (C - b)) % 26    
      return ''.join([ chr((( inv(clave[0], 26)*(ord(c) - ord('A') - clave[1])) % 26) + ord('A')) for c in mensaje_encriptado ])

    mensaje = input('Ingrese mensaje a encriptar\n')
    clave = [17, 20]
    Mensaje_encriptado = encrypt(mensaje, clave)
    print('Mensaje encriptado: ', Mensaje_encriptado )
    print('Mensaje desencriptado: ', decrypt(Mensaje_encriptado, clave) )

def p27():
    import string
    print("2.7 Cifrado de Sustitución Simple")
    def encrypt(mensaje, clave):
      
      
      alfabeto = string.ascii_lowercase
      dict_cifrado = dict(zip(alfabeto, clave.lower()))

    
      Mensaje_cifrado = ""
      for letter in mensaje.lower():
          
          if letter in dict_cifrado:
              Mensaje_cifrado += dict_cifrado[letter]
          
          else:
              Mensaje_cifrado += letter

      return Mensaje_cifrado

    def decrypt(mensaje_cifrado, clave):
    
    
      alfabeto = string.ascii_lowercase
      dict_cifrado = dict(zip(clave.lower(), alfabeto))

    
      mensaje = ""
      for letra in mensaje_cifrado.lower():
          
          if letra in dict_cifrado:
              mensaje += dict_cifrado[letra]
          
          else:
              mensaje += letra

      return mensaje

    clave = "QWERTYUIOPASDFGHJKLZXCVBNM"
    mensaje = input('Ingrese un mensaje para cifrar\n')
    mensaje_cifrado = encrypt(mensaje, clave)
    print('Encriptado: ',mensaje_cifrado)
    mensaje_desencriptado = decrypt(mensaje_cifrado, clave)
    print('Desencriptado: ', mensaje_desencriptado)

def p31():
    print("3.1 Calcular Diffie Hellman")

    while (True):
        
        p = int(input("\nIngrese un número primo p: "))

    
        if (isPrime(p)):
            break
        else:
            print(p, "no es un número primo")

    while (True):
        
        alpha = int(
            input("\nIngrese un α (generador del primo p) menor que p: "))

        if (alpha < p):
            break
        else:
            print("α debe ser menor que p")

    
    a = int(input("\nIngrese un valor para la clave privada a: "))
    b = int(input("Ingrese un valor para la clave privada b: "))

    
    A = (alpha ** a) % p
    B = (alpha ** b) % p

    
    s_A = (B ** a) % p
    s_B = (A ** b) % p

    
    if (s_A != s_B):
        print("Error en el cálculo de las claves compartidas")
        exit()

    
    print("\nNúmero primo p:", p)
    print("Generador α:", alpha)
    print("Clave privada a:", a)
    print("Clave privada b:", b)
    print("Clave pública A:", A)
    print("Clave pública B:", B)
    print("Clave compartida:", s_A)

    print("\nIngrese cualquier tecla para continuar...")
    input()

def p32():
    print("3.2 Calcular RSA")

    while (True):
        
        p = int(input("\nIngrese un número primo p: "))

        
        if (isPrime(p)):
            break
        else:
            print(p, "no es un número primo")

    while (True):
        
        q = int(input("\nIngrese un número primo q: "))

        
        if (q > p):
            
            if (isPrime(q)):
                break
            else:
                print(q, "no es un número primo")
        else:
            print("q debe ser mayor que p")

    
    n = p * q

    
    phi = (p - 1) * (q - 1)

    
    while (True):
        e = random.randint(1, phi)

        
        if gcd(e, phi) == 1:
            break

    
    d = pow(e, -1, phi)

    
    m = input("\nIngrese el mensaje a cifrar: ")

    if (m.isdigit()):
        m = int(m)

        
        c = pow(m, e, n)

        
        m2 = pow(c, d, n)
    else:
        
        c = [pow(ord(char), e, n) for char in m]

        
        m2 = ''.join([chr(pow(char, d, n)) for char in c])

    
    if (m != m2):
        print("Error en el descifrado")
        print("Escoja unos valores más alejados para p y q")
        exit()
        
    else:
        
        print("\nNúmero primo p: ", p)
        print("Número primo q: ", q)
        print("Valor público n: ", n)
        print("Indicador de Euler: ", phi)
        print("Valor público e: ", e)
        print("Valor privado d: ", d)
        print("Mensaje a cifrar: ", m)
        print("Mensaje cifrado: ", c)
        print("Mensaje descifrado: ", m2)

    print("\nIngrese cualquier tecla para continuar...")
    input()

def p33():
    print("3.3 Calcular Algoritmo De Exponenciación Rápida")

    
    b = int(input("\nIngrese la base: "))

    
    e = int(input("Ingrese el exponente: "))

    
    m = int(input("Ingrese el módulo: "))

    
    e = bin(e)[2:]

    
    x = 1
    x_aux = 1
    i = 0
    c = len(e) - 1

    while i < len(e):
        if e[i] == '1':
            x = ((x ** 2) * b) % m
            print("b" + str(c) + " = " + e[i] + " -> x = " + str(
                x_aux) + "² * " + str(b) + " mod " + str(m) + " = " + str(x))
            x_aux = x
        else:
            x = (x ** 2) % m
            print("b" + str(c) + " = " + e[i] + " -> x = " +
                  str(x_aux) + "² mod " + str(m) + " = " + str(x))
            x_aux = x
        i += 1
        c -= 1

    
    print("\nResultado:", x)

    print("\nIngrese cualquier tecla para continuar...")
    input()

# %%
from os import system

menuPrincipal = '''
================= MENU =================
========================================
1. Operaciones matematicas modulares.
2. Criptografia clasica.
3. Cirptografia moderna.
4. Salir.
========================================
'''

menuOp1 = '''
========= Matematicas modulares =========
=========================================
1. Modulo de dos numeros.
2. Inverso aditivo.
3. Inverso XOR.
4. Maximo comun divisor (GCD) e indicar si existe inverso multiplicativo.
5. Inverso multiplicativo por metodo tradicional.
6. Inverso multiplicativo usando AEE, indicando rondas y mostrando tabla de desarollo.
7. Atras.
========================================
'''

menuOp2 = '''
========== Criptografia clasica ==========
==========================================
1. Cifrado modulo 27.
2. Cifrado cesar.
3. Cifrado vernam.
4. Cifrado ATBASH.
5. Cifrado por transposicion columnar simple.
6. CIfrado afin.
7. Cifrado de sustitucion simple.
8. Atras.
=========================================
'''

menuOp3 = '''
========== Criptografia clasica ==========
==========================================
1. Diffie Hellman.
2. RSA.
3. Algoritmo exponenciacion rapida.
4. Atras.
=========================================
'''
while (True):
    system("cls")

    print(menuPrincipal)

    option = int(input())
    system("cls")

    if option == 1:
        while (True):
            system("cls")

            print(menuOp1)

            option = int(input())
            system("cls")

            if option == 1:
                p11()

            elif option == 2:
                p12()

            elif option == 3:
                p13()

            elif option == 4:
                p14()

            elif option == 5:
                p15()

            elif option == 6:
                p16()

            elif option == 7:
                break

            else:
                print("Opcion invalida\nPresione cualquier tecla para continuar")
                input()

    elif option == 2:
        while (True):
            system("cls")

            print(menuOp2)

            option = int(input())
            system("cls")

            if option == 1:
                p21()
                descifrarMod27()

            elif option == 2:
                p22()
                descifrarCesar()

            elif option == 3:
                p23()
                descifrarVernam()
               

            elif option == 4:
                p24()

            elif option == 5:
                p25()

            elif option == 6:
                p26()

            elif option == 7:
                p27()

            elif option == 8:
                break

            else:
                print("Opcion invalida\nPresione cualquier tecla para continuar")
                input()

    elif option == 3:
        while (True):
            system("cls")

            print(menuOp3)

            option = int(input())
            system("cls")

            if option == 1:
                p31()

            elif option == 2:
                p32()

            elif option == 3:
                p33()

            elif option == 4:
                break

            else:
                print("Opcion invalida\nPresione cualquier tecla para continuar")
                input()

    elif option == 4:
        break

    else:
        print("Opcion invalida\nPresione cualquier tecla para continuar")
        input()
